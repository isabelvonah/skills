# %%
import pandas as pd

# %%
pd.read_csv("offers.csv")
# Out:
#                                      id  \
# 0  6a24f7ee-fd7a-4246-bf62-57b384d609a9
# 1  32289881-3fa2-47e2-b9c4-d66348aa099e
# 2  32289881-3fa2-47e2-b9c4-d66348aa099e
# 3  32289881-3fa2-47e2-b9c4-d66348aa099e
#
#                                              title              date  \
# 0      Quantitative Financial Risk Manager (w/m/d)     25 March 2022
# 1  PostgreSQL & Oracle Database Administrator (VS)     21 March 2022
# 2                Datenmanager:in Sicherungsanlagen     10 March 2022
# 3            Senior Oracle Database Developer 100%  07 February 2022
#
#                  company              place    position    workload  \
# 0           die Mobiliar               Bern  Specialist  80% – 100%
# 1    PSS IT Solutions SA             Valais    Employee        100%
# 2            SBB CFF FFS  Zürich Altstetten    Employee  80% – 100%
# 3  Leonteq Securities AG             Zürich  Specialist        100%
#
#                                           categories  \
# ...
