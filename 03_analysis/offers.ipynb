# %%
import pandas as pd

# %%
offers = pd.read_csv("offers.csv")
offers
# Out:
#                                       id  \
# 0   863878fa-cd25-45d4-8d14-29bd23e18f33
# 1   ba1aad11-c8b9-4580-baad-c0e1876b1848
# 2   a1715571-0dcb-433b-8b9a-145e1b984bbf
# 3   a737b852-de1f-4909-b455-e6baef591018
# 4   0d7544cd-7276-48c1-b6ff-a354b1c0a8dd
# 5   abe65865-e4e6-49fc-988c-09cccde9b955
# 6   82a50161-491d-40fe-87e4-3066d3a580d1
# 7   d878ae68-e21e-4adc-b993-ed1f22512e2b
# 8   fdd74df7-9684-4f42-8930-4a25fb4911a4
# 9   8a44810c-1c8c-442c-af6a-1239eed5a852
# 10  c48db726-be6d-4250-9cd6-dffba0bed0af
# 11  cb74dda9-fcf0-4abd-be64-6133d8d258ff
# 12  681bdfa1-e949-4e47-b918-5007ce131835
# 13  a2c1be47-d56a-4186-933a-c12de74cb2f9
# 14  eb2828c4-cf19-416a-838f-29d1b77242bd
# 15  0f43aa17-d9b2-426b-b71d-6deb0d84ef86
# 16  bab38a4d-7340-4d96-b1b3-0a3531a929c2
# 17  5e2c8827-eedd-436c-ba1d-f76d2eb9badc
# 18  35a9ff25-391d-4c17-9354-b69ffa19efb3
# 19  62025f3a-4f6b-4ab9-aaa4-c26c83dd8aef
# 20  f1b9fcf9-e7ec-40e1-9a35-56f9f1115261
# 21  88a1389b-7afe-4062-afb7-380c5e47c30f
# ...

# %%
offers["text"]
# Out:
# 0      In einem Team von Fachspezialisten sind Sie ...
# 1      PostgreSQL & Oracle Database Administrator (...
# 2      Datenmanager:in Sicherungsanlagen\n\n    Das...
# 3      Senior Oracle Database Developer 100%\n\n\n\...
# Name: text, dtype: object
