# %%
import pandas as pd

# %%
offers = pd.read_csv("../01_scraping/03_scrape_offers.csv")
offers
# Out:
#                                          id  \
# 0      fc54ed14-95c4-48f2-8d72-b81d1f2f0012
# 1      f53ed11d-a658-4fe0-8876-8c8face12166
# 2      3cce1a92-2dae-4ef8-ac1c-765832639089
# 3      98085a5c-72a2-4bcd-86be-1fec0957ccdd
# 4      83b8fbca-8f70-4049-8d65-906323d35910
# ...                                     ...
# 36379  a2e042b6-a11f-4736-83bb-d07fb09f943e
# 36380  6bb83d6d-5e27-44db-8155-d8d68a468728
# 36381  fb2268a7-7fba-4fdc-ac70-57db1b4441c0
# 36382  a0be107b-29fa-4caf-becf-3fcd2eba0755
# 36383  97c5eafc-1a9d-45c6-b582-87c6d1ac0dd1
#
#                                                    title              date  \
# 0                          Windows Kernel Developer 100%     05 March 2022
# 1            Static Code Analysis - TypeScript Developer     04 March 2022
# 2                  Static Code Analysis - Java Developer     04 March 2022
# 3      Cloud Engineers / Cloud Architects (m/w/d), Re...     04 March 2022
# ...

# %%
offers["text"]
# Out:
# 0      DIV    Junior Projektleiter:in Online-Marketin...
# 1      IFRAME      Für unseren Kunden in Bern suchen ...
# 2      DIV    Trainee/Intern - Digital Marketing Spec...
# 3      IFRAME          Seit 1861 im Dienst des besten...
# 4                Wir suchen genau Sie und bieten gena...
#                              ...
# 208    IFRAME        Content Creator 100%\n\n        ...
# 209    DIV    Praktikant E-Commerce m/w 80-100%\n\n  ...
# 210    DIV    Digital Executive\n\n    .\n\n    BAT i...
# 211    DIV    Praktikant:in (m/w/d) Social Media - Zü...
# 212    DIV    Online Marketing Manager - 100 % (m/w/d...
# Name: text, Length: 213, dtype: object
