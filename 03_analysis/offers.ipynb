# %%
import pandas as pd

# %%
offers = pd.read_csv("03_scrape_offers.csv")
offers
# Out:
#                                        id  \
# 0    863878fa-cd25-45d4-8d14-29bd23e18f33
# 1    ba1aad11-c8b9-4580-baad-c0e1876b1848
# 2    a1715571-0dcb-433b-8b9a-145e1b984bbf
# 3    a737b852-de1f-4909-b455-e6baef591018
# 4    0d7544cd-7276-48c1-b6ff-a354b1c0a8dd
# ..                                    ...
# 208  60b6d107-f385-45bd-a5bb-85ab244c1cc1
# 209  82a50161-491d-40fe-87e4-3066d3a580d1
# 210  d878ae68-e21e-4adc-b993-ed1f22512e2b
# 211  2b715907-0c5c-420d-8aa3-84b964c82d42
# 212  cdac918d-8c72-49ee-abee-d14cf57d6688
#
#                                                  title              date  \
# 0    Junior Projektleiter:in Online-Marketing und S...     22 March 2022
# 1                 Digital Marketing Manager (m/w) 100%     08 April 2022
# 2        Trainee/Intern - Digital Marketing Specialist  14 February 2022
# 3    Praktikant Marketing / Content Management (m/w/d)     08 April 2022
# 4    Marketing Assistentin / Assistent befristet bi...     06 April 2022
# ...

# %%
offers["text"]
# Out:
# 0      DIV    Junior Projektleiter:in Online-Marketin...
# 1      IFRAME      Für unseren Kunden in Bern suchen ...
# 2      DIV    Trainee/Intern - Digital Marketing Spec...
# 3      IFRAME          Seit 1861 im Dienst des besten...
# 4                Wir suchen genau Sie und bieten gena...
#                              ...
# 208    IFRAME        Content Creator 100%\n\n        ...
# 209    DIV    Praktikant E-Commerce m/w 80-100%\n\n  ...
# 210    DIV    Digital Executive\n\n    .\n\n    BAT i...
# 211    DIV    Praktikant:in (m/w/d) Social Media - Zü...
# 212    DIV    Online Marketing Manager - 100 % (m/w/d...
# Name: text, Length: 213, dtype: object
