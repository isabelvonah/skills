# %%
import pandas as pd

# %%
offers = pd.read_csv("result_marketing-communications-editorial_product-brand-management.csv")
offers
# Out:
#                                         id  \
# 0     3120b30b-3efc-4792-b36c-ffe93ea5f2af
# 1     efc46ed6-157f-4cb4-bb0a-a19109ab22ef
# 2     63a711ba-40d7-4b13-8be8-5fa454e0d076
# 3     12539f67-dc3a-4c5f-82a8-8b56f2ef6dc7
# 4     4ddfab9e-4579-4f99-9d81-45de5e1af65d
# ...                                    ...
# 1212  bb3bd6c8-6f14-4d10-8089-113b10bd0326
# 1213  1c5f1d05-694d-4406-b61a-959c207e6729
# 1214  2c9acdc7-93a5-41a0-b26f-c96f37c0437f
# 1215  5a36ac25-84b7-4d00-b483-ec07e387bf4a
# 1216  bb8dba1f-2440-4398-a5e8-49a9bb468508
#
#                                      cat                    subcat  \
# 0     marketing-communications-editorial  product-brand-management
# 1     marketing-communications-editorial  product-brand-management
# 2     marketing-communications-editorial  product-brand-management
# 3     marketing-communications-editorial  product-brand-management
# 4     marketing-communications-editorial  product-brand-management
# ...

# %%
offers.drop_duplicates(subset="id")
# Out:
#                                         id  \
# 0     3120b30b-3efc-4792-b36c-ffe93ea5f2af
# 1     efc46ed6-157f-4cb4-bb0a-a19109ab22ef
# 2     63a711ba-40d7-4b13-8be8-5fa454e0d076
# 3     12539f67-dc3a-4c5f-82a8-8b56f2ef6dc7
# 4     4ddfab9e-4579-4f99-9d81-45de5e1af65d
# ...                                    ...
# 1211  4df8cc00-4c6f-44cc-be77-c4c6b590fcf7
# 1212  bb3bd6c8-6f14-4d10-8089-113b10bd0326
# 1213  1c5f1d05-694d-4406-b61a-959c207e6729
# 1215  5a36ac25-84b7-4d00-b483-ec07e387bf4a
# 1216  bb8dba1f-2440-4398-a5e8-49a9bb468508
#
#                                      cat                    subcat  \
# 0     marketing-communications-editorial  product-brand-management
# 1     marketing-communications-editorial  product-brand-management
# 2     marketing-communications-editorial  product-brand-management
# 3     marketing-communications-editorial  product-brand-management
# 4     marketing-communications-editorial  product-brand-management
# ...

# %%
offers["id"].value_counts().head(20)
# Out:
# afe9fa32-d163-4adc-8744-90ff8eb1974c    4
# 3120b30b-3efc-4792-b36c-ffe93ea5f2af    3
# 8c75899d-590e-4397-905d-1560cbba226f    3
# 24464047-68a9-4804-90fd-9874709dd534    3
# 6ff85d41-32dd-4b99-a20c-65c5e9574f68    3
# ed3728db-6c8d-4146-9ee1-12c9eda200c1    3
# 00fe1850-100b-4a50-a467-fb0b11be0929    3
# 562d7229-5b96-4c09-8511-64e3cd17c5d5    3
# e048a31b-8f5d-44eb-b22a-2c4dea0755ca    3
# f6f4771a-5681-47da-bb74-5e4276212891    3
# 0337bbd1-de70-4483-97f6-8ee591200e28    3
# 23ded8dd-3ffc-4427-9295-baa01cbbf695    3
# 902ecdfb-7800-4e7a-854c-0661bc933f7b    3
# ac52a729-8701-4365-9eba-6a39c0dad26a    3
# d24e7a6d-a85b-458b-ad33-b1e48b866172    3
# 63a711ba-40d7-4b13-8be8-5fa454e0d076    3
# 12539f67-dc3a-4c5f-82a8-8b56f2ef6dc7    3
# f122c175-3cb8-48ce-b126-3206ccb0152b    3
# e1d3d8b7-d997-463d-9e0c-716faf6b0f61    2
# 5536f9a6-2222-41c9-b758-bbde3715de7e    2
# Name: id, dtype: int64

# %%
offers[offers["id"] == "5745af7a-1f9b-4ce4-96f1-2f0da8b0dffb"]
# Out:
# Empty DataFrame
# Columns: [id, cat, subcat, employment-typ, industry, page, title, company, place, promo, date]
# Index: []
