# %%
import pandas as pd

# %%
offers = pd.read_csv("result_purchasing-logistics-trading_logistics-supply-chain.csv")
offers
# Out:
#                                         id                           cat  \
# 0     a634a4e7-b7b7-41ca-b58f-0d17f3c8470e  purchasing-logistics-trading
# 1     d9e7aac6-4040-4eaf-b61c-a7189923d338  purchasing-logistics-trading
# 2     1c426b66-be08-4e7c-8e6f-b5118925a6b5  purchasing-logistics-trading
# 3     1556ef83-b99d-4824-9a8a-227821d94751  purchasing-logistics-trading
# 4     774dcc05-2044-4cd3-b204-74b01eb035ab  purchasing-logistics-trading
# ...                                    ...                           ...
# 1526  32e9210f-1266-4844-9294-e3d4648e080f  purchasing-logistics-trading
# 1527  d35b0d0a-7d00-4fca-8f5d-c0298bd67755  purchasing-logistics-trading
# 1528  86a8bd37-a9e5-4845-873e-ba9304d2dd20  purchasing-logistics-trading
# 1529  3dc602a8-56b8-4e2a-af20-3b1b0fac8983  purchasing-logistics-trading
# 1530  bf748efa-6171-481b-b67f-86b88f4276e8  purchasing-logistics-trading
#
#                       subcat  employment-typ  industry  page  \
# 0     logistics-supply-chain               1         5     1
# 1     logistics-supply-chain               1         5     1
# 2     logistics-supply-chain               1         5     1
# 3     logistics-supply-chain               1         5     1
# 4     logistics-supply-chain               1         5     1
# ...                      ...             ...       ...   ...
# 1526  logistics-supply-chain               6        21     1
# 1527  logistics-supply-chain               6        22     1
# 1528  logistics-supply-chain               6        22     1
# 1529  logistics-supply-chain               6        22     1
# 1530  logistics-supply-chain               6        22     1
#
#                                                   title  \
# 0     (Senior) Specialists, Customer & Logistics Pla...
# 1                                  Distribution Manager
# 2                             Logistiker EFZ (m/w) 100%
# 3     Fachfrau/-mann Import/Export // Johnson & Johnson
# 4                                        Logistiker EFZ
# ...                                                 ...
# 1526      Lehrstelle Strassentransportfachmann/frau EFZ
# 1527     Lernende/r Strassentransportfachfrau/-mann EFZ
# 1528  Lehrstelle 2022: Strassentransportfachmann/-fr...
# 1529  Lehrstelle 2022 Strassentransportfachfrau / St...
# 1530  Lehrstelle als Strassentransportfachmann/-frau...
#
#                                                 company  \
# 0     AurigaVision AG Executive Search Pharma- und H...
# 1                           Kelly Services (Schweiz) AG
# 2                             Personal Contact Basel AG
# 3          Randstad (Schweiz) AG, c/o Johnson & Johnson
# 4                                       We make it GmbH
# ...                                                 ...
# 1526                ETA SA Manufacture Horlogère Suisse
# 1527                                         Frauenfeld
# 1528                                         Regensdorf
# 1529                                             Zürich
# 1530                         Schneider Umweltservice AG
#
#                                                place  promo  \
# 0     Neuchâtel area, flexibility reg. work location   True
# 1                                              Basel  False
# 2                                      Region Aargau  False
# 3                                               Bern  False
# 4                                        Region Bern  False
# ...                                              ...    ...
# 1526                                   2540 Grenchen  False
# 1527                                             NaN  False
# 1528                                             NaN  False
# 1529                                             NaN  False
# 1530                                  Meilen, Perlen  False
#
#                                                    date
# 0     (datetime.datetime(2022, 4, 8, 18, 52, 22, 596...
# 1     (datetime.datetime(2022, 4, 8, 18, 52, 22, 598...
# 2     (datetime.datetime(2022, 4, 8, 18, 52, 22, 598...
# 3     (datetime.datetime(2022, 4, 8, 18, 52, 22, 599...
# 4     (datetime.datetime(2022, 4, 8, 18, 52, 22, 600...
# ...                                                 ...
# 1526  (datetime.datetime(2022, 4, 8, 19, 2, 29, 2905...
# 1527  (datetime.datetime(2022, 4, 8, 19, 2, 30, 1429...
# 1528  (datetime.datetime(2022, 4, 8, 19, 2, 30, 1430...
# 1529  (datetime.datetime(2022, 4, 8, 19, 2, 30, 1431...
# 1530  (datetime.datetime(2022, 4, 8, 19, 2, 30, 1432...
#
# [1531 rows x 11 columns]

# %%
offers.drop_duplicates(subset="id")
# Out:
#                                         id                           cat  \
# 0     a634a4e7-b7b7-41ca-b58f-0d17f3c8470e  purchasing-logistics-trading
# 1     d9e7aac6-4040-4eaf-b61c-a7189923d338  purchasing-logistics-trading
# 2     1c426b66-be08-4e7c-8e6f-b5118925a6b5  purchasing-logistics-trading
# 3     1556ef83-b99d-4824-9a8a-227821d94751  purchasing-logistics-trading
# 4     774dcc05-2044-4cd3-b204-74b01eb035ab  purchasing-logistics-trading
# ...                                    ...                           ...
# 1508  e1a71d78-9004-4b9b-af09-cd254bc47001  purchasing-logistics-trading
# 1510  e8beeaa8-e3a2-47dc-8f8f-1fcb4be3be13  purchasing-logistics-trading
# 1511  baf5290c-2e09-4fcb-b64a-20791790c237  purchasing-logistics-trading
# 1514  986967be-e4a2-40c1-9db0-80f0b3bfa72d  purchasing-logistics-trading
# 1525  51012ea5-06d3-469f-810c-fccd79e6ca6e  purchasing-logistics-trading
#
#                       subcat  employment-typ  industry  page  \
# 0     logistics-supply-chain               1         5     1
# 1     logistics-supply-chain               1         5     1
# 2     logistics-supply-chain               1         5     1
# 3     logistics-supply-chain               1         5     1
# 4     logistics-supply-chain               1         5     1
# ...                      ...             ...       ...   ...
# 1508  logistics-supply-chain               6         8     1
# 1510  logistics-supply-chain               6        11     1
# 1511  logistics-supply-chain               6        12     1
# 1514  logistics-supply-chain               6        18     1
# 1525  logistics-supply-chain               6        21     1
#
#                                                   title  \
# 0     (Senior) Specialists, Customer & Logistics Pla...
# 1                                  Distribution Manager
# 2                             Logistiker EFZ (m/w) 100%
# 3     Fachfrau/-mann Import/Export // Johnson & Johnson
# 4                                        Logistiker EFZ
# ...                                                 ...
# 1508               Lehrstelle Logistiker EFZ 2022 (m/w)
# 1510              Lehrstelle als Logistiker EFZ (m/w/d)
# 1511  Lehrstelle LogistikerIn EFZ für Sommer 2022 in...
# 1514  Ausbildung Disponent / Disponentin SBB Cargo I...
# 1525                Lehrstelle als Logistiker EFZ (w/m)
#
#                                                 company  \
# 0     AurigaVision AG Executive Search Pharma- und H...
# 1                           Kelly Services (Schweiz) AG
# 2                             Personal Contact Basel AG
# 3          Randstad (Schweiz) AG, c/o Johnson & Johnson
# 4                                       We make it GmbH
# ...                                                 ...
# 1508                                         Repower AG
# 1510                                Kiener + Wittlin AG
# 1511                            Assa Abloy (Schweiz) AG
# 1514                         SBB Cargo International AG
# 1525                        HOCHDORF Swiss Nutrition AG
#
#                                                place  promo  \
# 0     Neuchâtel area, flexibility reg. work location   True
# 1                                              Basel  False
# 2                                      Region Aargau  False
# 3                                               Bern  False
# 4                                        Region Bern  False
# ...                                              ...    ...
# 1508                                          Küblis  False
# 1510                                  Münchenbuchsee  False
# 1511                                     Kleinlützel  False
# 1514                                           Olten  False
# 1525                                          Sulgen  False
#
#                                                    date
# 0     (datetime.datetime(2022, 4, 8, 18, 52, 22, 596...
# 1     (datetime.datetime(2022, 4, 8, 18, 52, 22, 598...
# 2     (datetime.datetime(2022, 4, 8, 18, 52, 22, 598...
# 3     (datetime.datetime(2022, 4, 8, 18, 52, 22, 599...
# 4     (datetime.datetime(2022, 4, 8, 18, 52, 22, 600...
# ...                                                 ...
# 1508  (datetime.datetime(2022, 4, 8, 19, 1, 46, 6013...
# 1510  (datetime.datetime(2022, 4, 8, 19, 1, 51, 1730...
# 1511  (datetime.datetime(2022, 4, 8, 19, 1, 54, 1688...
# 1514  (datetime.datetime(2022, 4, 8, 19, 2, 20, 4134...
# 1525  (datetime.datetime(2022, 4, 8, 19, 2, 29, 2904...
#
# [1437 rows x 11 columns]

# %%
offers[offers["id"].value_counts() > 2]
# Out:
# /tmp/ipykernel_32545/3141071446.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   offers[offers["id"].value_counts() > 2]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 offers[offers["id"].value_counts() > 2]
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:3497, in DataFrame.__getitem__(self, key)
#    3495 # Do we have a (boolean) 1d indexer?
#    3496 if com.is_bool_indexer(key):
# -> 3497     return self._getitem_bool_array(key)
#    3499 # We are left with two options: a single key, and a collection of keys,
#    3500 # We interpret tuples as collections only for non-MultiIndex
#    3501 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:3550, in DataFrame._getitem_bool_array(self, key)
#    3544     raise ValueError(
#    3545         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3546     )
#    3548 # check_bool_indexer will throw exception if Series key cannot
#    3549 # be reindexed to match DataFrame rows
# -> 3550 key = check_bool_indexer(self.index, key)
#    3551 indexer = key.nonzero()[0]
#    3552 return self._take_with_is_copy(indexer, axis=0)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexing.py:2375, in check_bool_indexer(index, key)
#    2373     mask = isna(result._values)
#    2374     if mask.any():
# -> 2375         raise IndexingError(
#    2376             "Unalignable boolean Series provided as "
#    2377             "indexer (index of the boolean Series and of "
#    2378             "the indexed object do not match)."
#    2379         )
#    2380     return result.astype(bool)._values
#    2381 if is_object_dtype(key):
#    2382     # key might be object-dtype bool, check_array_indexer needs bool array
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
offers[offers["id"] == "5745af7a-1f9b-4ce4-96f1-2f0da8b0dffb"]
# Out:
#                                       id                             cat  \
# 0   5745af7a-1f9b-4ce4-96f1-2f0da8b0dffb  information-technology-telecom
# 68  5745af7a-1f9b-4ce4-96f1-2f0da8b0dffb  information-technology-telecom
#
#                               subcat  employment-typ  page  \
# 0   database-specialists-development               5     1
# 68  database-specialists-development               5     3
#
#                                                 title  \
# 0   Chef des département de la centrale d'alarme 1...
# 68  Chef des département de la centrale d'alarme 1...
#
#                                  company     place  promo  \
# 0   Logjob AG - For Supply Chain Experts  Lausanne   True
# 68  Logjob AG - For Supply Chain Experts  Lausanne  False
#
#                                                  date
# 0   (datetime.datetime(2022, 3, 31, 11, 24, 24, 19...
# 68  (datetime.datetime(2022, 3, 31, 11, 24, 25, 13...
